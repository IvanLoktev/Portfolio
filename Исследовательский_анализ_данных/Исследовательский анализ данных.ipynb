# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод:-В-данном-датафрейме-достаточно-много-строк-с-пропущенными-значениями,-видно-много-выбивающихся-значений-по-максимальным-показателям,-например-в-таких-показателях-как-количество-комнат,-общая-площадь,-жилая-площадь,-высота-потолков.-Необходимо-изменить-формат-значений-в-столбце-'first_day_exposition'-и-изменить-тип-данных-на-целочисленный-в-столбцах-'floor',-'floors_total',-'days_exposition',-'balcony',-а-в-столбце-'is_apartment'-поменять-формат-на-'bool'.-В-датафрейме-отсутсвуют-null-значения." data-toc-modified-id="Вывод:-В-данном-датафрейме-достаточно-много-строк-с-пропущенными-значениями,-видно-много-выбивающихся-значений-по-максимальным-показателям,-например-в-таких-показателях-как-количество-комнат,-общая-площадь,-жилая-площадь,-высота-потолков.-Необходимо-изменить-формат-значений-в-столбце-'first_day_exposition'-и-изменить-тип-данных-на-целочисленный-в-столбцах-'floor',-'floors_total',-'days_exposition',-'balcony',-а-в-столбце-'is_apartment'-поменять-формат-на-'bool'.-В-датафрейме-отсутсвуют-null-значения.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод: В данном датафрейме достаточно много строк с пропущенными значениями, видно много выбивающихся значений по максимальным показателям, например в таких показателях как количество комнат, общая площадь, жилая площадь, высота потолков. Необходимо изменить формат значений в столбце 'first_day_exposition' и изменить тип данных на целочисленный в столбцах 'floor', 'floors_total', 'days_exposition', 'balcony', а в столбце 'is_apartment' поменять формат на 'bool'. В датафрейме отсутсвуют null значения.</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-пропусков." data-toc-modified-id="Обработка-пропусков.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обработка пропусков.</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра." data-toc-modified-id="Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.</a></span></li><li><span><a href="#Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?" data-toc-modified-id="Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?</a></span></li><li><span><a href="#Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили." data-toc-modified-id="Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.</a></span></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.</a></span></li><li><span><a href="#Изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Изучите зависимость от даты размещения: дня недели, месяца и года.</a></span></li><li><span><a href="#Зависимость-цены-от-того,-на-каком-этаже-расположена-квартира." data-toc-modified-id="Зависимость-цены-от-того,-на-каком-этаже-расположена-квартира.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Зависимость цены от того, на каком этаже расположена квартира.</a></span></li><li><span><a href="#Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-среди-них-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-'locality_name'." data-toc-modified-id="Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-среди-них-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-'locality_name'.-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце 'locality_name'.</a></span></li><li><span><a href="#Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-('locality_name').-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется-—-это-и-будет-центральная-зона." data-toc-modified-id="Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-('locality_name').-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется-—-это-и-будет-центральная-зона.-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге ('locality_name'). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.</a></span></li><li><span><a href="#Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?" data-toc-modified-id="Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# 1.Вызвал библиотеку pandas.

# %%
import pandas as pd
#import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 2.Прочитал содержимое файла real_estate_data.csv и сохранил его в датафрейме apartments_for_sale.

# %%
apartments_for_sale = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# 3.Ознакомился со сводной информацией в таблице, вызвав метод info().

# %%
apartments_for_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# 4.Ознакомился с данными вызвав метод head().

# %%
apartments_for_sale.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %% [markdown]
# 5.Ознакомился с данными вызвав методы describe().

# %%
apartments_for_sale.describe(include='all').T
# Out:
#                       count unique                  top   freq         mean  \
# total_images          23699    NaN                  NaN    NaN      9.85848
# last_price            23699    NaN                  NaN    NaN  6.54155e+06
# total_area            23699    NaN                  NaN    NaN      60.3487
# first_day_exposition  23699   1491  2018-02-01T00:00:00    368          NaN
# rooms                 23699    NaN                  NaN    NaN      2.07064
# ceiling_height        14504    NaN                  NaN    NaN       2.7715
# floors_total          23613    NaN                  NaN    NaN      10.6738
# living_area           21796    NaN                  NaN    NaN      34.4579
# floor                 23699    NaN                  NaN    NaN      5.89236
# is_apartment           2775      2                False   2725          NaN
# studio                23699      2                False  23550          NaN
# ...

# %% [markdown]
# ### Вывод: В данном датафрейме достаточно много строк с пропущенными значениями, видно много выбивающихся значений по максимальным показателям, например в таких показателях как количество комнат, общая площадь, жилая площадь, высота потолков. Необходимо изменить формат значений в столбце 'first_day_exposition' и изменить тип данных на целочисленный в столбцах 'floor', 'floors_total', 'days_exposition', 'balcony', а в столбце 'is_apartment' поменять формат на 'bool'. В датафрейме отсутсвуют null значения.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Обработка пропусков.

# %% [markdown]
# 1. Подсчитал пропущенные значения методами isnull() и sum().

# %%
apartments_for_sale.isnull().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# 2. Произвел замену пропущенных значений в столбце 'balcony' методом fillna() на 0 и произвел изменение типа данных данного столбца на integer, т.к количество балконов должно быть целочисленным. Значения NaN указывают на отсутствие балконов, логичнее их заменить на 0.

# %%
apartments_for_sale['balcony'] = apartments_for_sale['balcony'].fillna(0)
apartments_for_sale['balcony'] = apartments_for_sale['balcony'].astype('int')

# %% [markdown]
# 3. Произвел замену пропущенных значений в столбце'is_apartment' методом fillna() на False и поменял тип данных на bool т.к столбец должен иметь булев тип данных.

# %%
apartments_for_sale['is_apartment'] = apartments_for_sale['is_apartment'].fillna(False)
apartments_for_sale['is_apartment'] = apartments_for_sale['is_apartment'].astype('bool')

# %% [markdown]
# 4. Произвел замену пропущенных значений в столбце 'days_exposition' методом fillna() на 0 и произвел изменение типа данных данного столбца на integer, т.к количество дней публикации объявления должно быть целочисленным. Возможно пропуски в этом столбце обусловлены тем, что ни дня не прошло с момента публикации объявления, поэтому я заменил значения NaN на 0.

# %%
apartments_for_sale['days_exposition'] = apartments_for_sale['days_exposition'].fillna(0)
apartments_for_sale['days_exposition'] = apartments_for_sale['days_exposition'].astype('int')

# %% [markdown]
# 5. Произвел замену пропущенных значений в столбце 'kitchen_area' методом fillna() на 0. Существуют квартиры без кухни, поэтому площадь кухни будет иметь нулевое значение вместо NaN.

# %%
apartments_for_sale['kitchen_area'] = apartments_for_sale['kitchen_area'].fillna(0)

# %% [markdown]
# 6. Произвел замену пропущенных значений в столбце 'living_area' методом fillna() на 0. В столбце total_area нету пропущенных значений. Пропусков в столбце 'living_area' - 1903, а сумма квартир со свободной планировкой и апартаментов равна - 2204. Значит либо это апартаменты, либо квартира со свободной планировкой в которой жилая площадь еще не определена.

# %%
find_nan = apartments_for_sale.loc[apartments_for_sale.loc[:,'open_plan'] == True].count().sum()
find_nan_1 = apartments_for_sale.loc[apartments_for_sale.loc[:,'is_apartment'] == True].count().sum()
print(find_nan+find_nan_1)
# Out:
# 2203

# %%
apartments_for_sale['living_area'] = apartments_for_sale['living_area'].fillna(0)

# %% [markdown]
# 7. Произвел замену пропущенных значений в столбце 'ceiling_height' на '' методом fillna().

# %%
apartments_for_sale['ceiling_height'] = apartments_for_sale['ceiling_height'].fillna(0)

# %% [markdown]
# 8. Произвел замену пропущенных значений в столбце 'cityCenters_nearest' на '' методом fillna().

# %%
apartments_for_sale['cityCenters_nearest'] = apartments_for_sale['cityCenters_nearest'].fillna(0)

# %% [markdown]
# 9. Удаляю строки c пропусками в столбце 'floors_total'. В столбце 'floors_total' 86 строк с пропущенными значениями, в сравнении с нашим датафреймом в 23699 строк, мы теряем меньше полпроцента информации. Изменяю тип данных столбца 'floors_total' на int т.к количество этажей в доме должно быть целочисленным.

# %%
apartments_for_sale.dropna(subset=['floors_total'], inplace=True)
apartments_for_sale['floors_total'] = apartments_for_sale['floors_total'].astype('int')
apartments_for_sale.isnull().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              48
# airports_nearest         5532
# cityCenters_nearest         0
# parks_around3000         5508
# parks_nearest           15568
# ponds_around3000         5508
# ponds_nearest           14552
# days_exposition             0
# dtype: int64

# %% [markdown]
# 10. Вывел средние показатели по использованию памяти для данных разных типов.

# %%
for dtype in ['float','int','object']:
    selected_dtype = apartments_for_sale.select_dtypes(include=[dtype])
    mean_usage_b = selected_dtype.memory_usage(deep=True).mean()
    mean_usage_mb = mean_usage_b / 1024 ** 2
    print("Average memory usage for {} columns: {:03.2f} MB".format(dtype,mean_usage_mb))
# Out:
# Average memory usage for float columns: 0.18 MB
# Average memory usage for int columns: 0.18 MB
# Average memory usage for object columns: 1.46 MB

# %% [markdown]
# 11. Написал функцию для нисходящего преобразования числовых типов.

# %%
def mem_usage(pandas_obj):
    if isinstance(pandas_obj,pd.DataFrame):
        usage_b = pandas_obj.memory_usage(deep=True).sum()
    else: 
        usage_b = pandas_obj.memory_usage(deep=True)
    usage_mb = usage_b / 1024 ** 2 
    return "{:03.2f} MB".format(usage_mb)

# %% [markdown]
# 12. Снизил потребление памяти для целочисленных значений, более чем на 50 %.

# %%
apartments_for_sale_int = apartments_for_sale.select_dtypes(include=['int'])
converted_int = apartments_for_sale_int.apply(pd.to_numeric,downcast='unsigned')

print(mem_usage(apartments_for_sale_int))
print(mem_usage(converted_int))

compare_ints = pd.concat([apartments_for_sale_int.dtypes,converted_int.dtypes],axis=1)
compare_ints.columns = ['before','after']
compare_ints.apply(pd.Series.value_counts)
# Out:
# 1.26 MB
# 0.34 MB
#         before  after
# uint8      NaN    5.0
# uint16     NaN    1.0
# int64      6.0    NaN

# %% [markdown]
# 13. Снизил потребление памяти для чисел с плавающей точкой, на 37.8 %.

# %%
apartments_for_sale_float = apartments_for_sale.select_dtypes(include=['float'])
converted_float = apartments_for_sale_float.apply(pd.to_numeric,downcast='float')

print(mem_usage(apartments_for_sale_float))
print(mem_usage(converted_float))

compare_floats = pd.concat([apartments_for_sale_float.dtypes,converted_float.dtypes],axis=1)
compare_floats.columns = ['before','after']
compare_floats.apply(pd.Series.value_counts)
# Out:
# 2.16 MB
# 1.17 MB
#          before  after
# float32     NaN   11.0
# float64    11.0    NaN

# %% [markdown]
# 15. Снизил потребление памяти для значений типа строка на 95.9%.

# %%
apartments_for_sale_obj = apartments_for_sale.select_dtypes(include=['object']).copy()
apartments_for_sale_obj.describe()
# Out:
#        first_day_exposition    locality_name
# count                 23613            23565
# unique                 1489              364
# top     2018-02-01T00:00:00  Санкт-Петербург
# freq                    366            15651

# %%
dow = apartments_for_sale_obj.locality_name
print(dow.head())

dow_cat = dow.astype('category')
print(dow_cat.head())
# Out:
# 0    Санкт-Петербург
# 1     посёлок Шушары
# 2    Санкт-Петербург
# 3    Санкт-Петербург
# 4    Санкт-Петербург
# Name: locality_name, dtype: object
# 0    Санкт-Петербург
# 1     посёлок Шушары
# 2    Санкт-Петербург
# 3    Санкт-Петербург
# 4    Санкт-Петербург
# Name: locality_name, dtype: category
# Categories (364, object): [Бокситогорск, Волосово, Волхов, Всеволожск, ..., село Рождествено, село Русско-Высоцкое, село Старая Ладога, село Шум]

# %%
print(mem_usage(dow))
print(mem_usage(dow_cat))
# Out:
# 2.66 MB
# 0.28 MB

# %%
converted_obj = pd.DataFrame()

for col in apartments_for_sale_obj.columns:
    num_unique_values = len(apartments_for_sale_obj[col].unique())
    num_total_values = len(apartments_for_sale_obj[col])
    if num_unique_values / num_total_values < 0.5:
        converted_obj.loc[:,col] = apartments_for_sale_obj[col].astype('category')
    else:
        converted_obj.loc[:,col] = apartments_for_sale_obj[col]

# %%
print(mem_usage(apartments_for_sale_obj))
print(mem_usage(converted_obj))

compare_obj = pd.concat([apartments_for_sale_obj.dtypes,converted_obj.dtypes],axis=1)
compare_obj.columns = ['before','after']
compare_obj.apply(pd.Series.value_counts)
# Out:
# 4.37 MB
# 0.47 MB
#           before  after
# object       2.0    NaN
# category     NaN    1.0
# category     NaN    1.0

# %% [markdown]
# 14. По всему датафрейму потребление памяти снизилось на 82.9%.

# %%
optimized_apartments_for_sale = apartments_for_sale.copy()

optimized_apartments_for_sale[converted_int.columns] = converted_int
optimized_apartments_for_sale[converted_float.columns] = converted_float
optimized_apartments_for_sale[converted_obj.columns] = converted_obj


print(mem_usage(apartments_for_sale))
print(mem_usage(optimized_apartments_for_sale))
# Out:
# 7.51 MB
# 1.68 MB

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# 1. Посчитал цену квадратного метра.

# %%
price_column = apartments_for_sale['last_price']
area_column = apartments_for_sale['total_area']
price_area = price_column / area_column
apartments_for_sale['price_area'] = price_area

# %% [markdown]
# 2. Создал отдельные столбцы 'weekday', 'year', 'month' в которых хранятся день недели, год и месяц публикации объявления.

# %%
apartments_for_sale['first_day_exposition'] = pd.to_datetime(apartments_for_sale['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
apartments_for_sale['weekday'] = apartments_for_sale['first_day_exposition'].dt.weekday
apartments_for_sale['year'] = apartments_for_sale['first_day_exposition'].dt.year
apartments_for_sale['month'] = apartments_for_sale['first_day_exposition'].dt.month
apartments_for_sale.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            0.00            11         18.6      1         False  ...
# 2            0.00             5         34.3      4         False  ...
# 3            0.00            14          0.0      9         False  ...
# 4            3.03            14         32.0     13         False  ...
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# ...

# %% [markdown]
# 3. этаж квартиры; варианты — первый, последний, другой.

# %%
apartments_for_sale['floor'] = apartments_for_sale['floor'].where(apartments_for_sale['floor'] != 1, 'первый')
apartments_for_sale['floor'] = apartments_for_sale['floor'].where(apartments_for_sale['floor'] != apartments_for_sale['floors_total'], 'последний')
apartments_for_sale['floor'] = apartments_for_sale['floor'].where((apartments_for_sale['floor'] == 'первый') | (apartments_for_sale['floor'] == 'последний'), 'другой')
apartments_for_sale.head(15)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 3              0  64900000.0      159.00           2015-07-24      3
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
# ...

# %% [markdown]
# 4. Создал переменные: living_area_column, total_area_column, kitchen_area_column, которым присвоены столбцы со значением площадей.В переменных ratio_area, ratio_area1 посчитал соотношение жилой и общей площади, а также отношение площади кухни к общей. Создал столбцы 'ratio_area_living', 'ratio_area_kitchen' в которых хранятся значения соотношений площадей.

# %%
living_area_column = apartments_for_sale['living_area']
total_area_column = apartments_for_sale['total_area']
kitchen_area_column = apartments_for_sale['kitchen_area']
ratio_area = living_area_column / total_area_column
ratio_area1 = kitchen_area_column / total_area_column
apartments_for_sale['ratio_area_living'] = ratio_area
apartments_for_sale['ratio_area_kitchen'] = ratio_area1

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.

# %% [markdown]
# 1. Построил гистограмму по столбцу 'total_area' методом plot(), чтобы изучить частоту разных значений площади квартир.

# %%
apartments_for_sale.plot(y='total_area',title='Total_area', grid=True, kind='hist', bins=10, range=(0, 200))
plt.show()

# %% [markdown]
# 2. Построил гистограмму по столбцу 'last_price' методом plot(), чтобы изучить частоту разных значений цены квартир.

# %%
apartments_for_sale.plot(y='last_price',title='Price_apartments', grid=True, kind='hist', bins=10, range=(0, 15000000))
plt.show()

# %% [markdown]
# 3. Построил гистограмму по столбцу 'rooms' методом plot(), чтобы изучить частоту разных значений количества комнат в квартире.

# %%
apartments_for_sale.plot(y='rooms',title='Rooms', grid=True, kind='hist', bins=10, range=(0, 10))
plt.show()

# %% [markdown]
# 4. Построил гистограмму по столбцу 'ceiling_height' методом hist(), чтобы изучить частоту разных значений высот потолка в квартире.

# %%
apartments_for_sale.plot(y='ceiling_height', title='Ceiling_height', grid=True, kind='hist', bins=10, range=(2, 4))
plt.show()

# %% [markdown]
# * Вывод: Распределения на гистограммах по параметрам: площадь, цена, число комнат, высота потолков, имеют характер нормального распределения.

# %% [markdown]
# ### Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %% [markdown]
# 1. Построил гистограмму по столбцу 'days_exposition'методом hist(), чтобы оценить частоту количества дней публикации объявления о продаже.

# %%
apartments_for_sale.plot(y='days_exposition', title='Days_exposition', grid=True, kind='hist', bins=10, range=(0, 100))
plt.show()

# %% [markdown]
# 2. Посчитал среднее и медиану методом describe().

# %%
apartments_for_sale['days_exposition'].describe()
# Out:
# count    23613.000000
# mean       156.586075
# std        213.502550
# min          0.000000
# 25%         22.000000
# 50%         73.000000
# 75%        199.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# * Вывод: Опираясь на полученные данные, больше всего продаж проходят в течение 1-3 месяцев. Очень быстрой продажей, можно считать продажу в день публикации. Очень долгой продажей, можно считать продажу реализованную после года с момента публикации.

# %% [markdown]
# ### Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.

# %% [markdown]
# 1. Удалил строку с необычно долгим временем продажи квартиры, а точнее с максимальным временем продажи.

# %%
#string=apartments_for_sale.loc[apartments_for_sale.loc[:,'days_exposition'] == 1580]
#print(string)

# %%
#apartments_for_sale = apartments_for_sale.drop(index=[18843])

# %% [markdown]
# 2. Размеры потолков свыше 4м это выбивающиеся значения.

# %%
apartments_for_sale = apartments_for_sale.query('ceiling_height < 4')

# %% [markdown]
# 3. Оставлю значения общей площади до 350 квадратных метров.

# %%
apartments_for_sale = apartments_for_sale.query('total_area < 350')

# %% [markdown]
# 4. Количество комнат сокращу до 10.

# %%
apartments_for_sale = apartments_for_sale.query('rooms < 10')

# %% [markdown]
# * Вывод: Оставил характеристики квартир, которые чаще распространены. Убрал значения необычно больших показателей высот потолков, общей площади и количества комнат.

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.

# %% [markdown]
# 1. Построил график зависимости цены от площади обращаясь к pivot_table() и используя метод plot().

# %%
apartments_for_sale.pivot_table(index='total_area', values='last_price').plot(grid=True, title='Price_from_Area', figsize=(12, 8));

# %% [markdown]
# * Вывод: На графике видна зависимость увеличения цены квартиры в зависимости от площади, но т.к это не единственный фактор влияющий на стоимость квартиры график не имеет характер линейной зависимости.

# %% [markdown]
# 2. Построил график зависимости цены от количества комнат обращаясь к pivot_table() и используя метод plot().

# %%
apartments_for_sale.pivot_table(index='rooms', values='last_price').plot(grid=True,title='Price_from_Rooms', figsize=(10, 9));

# %% [markdown]
# 3. Построил график зависимости цены от удаленности от центра обращаясь к pivot_table() и используя метод plot().

# %%
apartments_for_sale.pivot_table(index='cityCenters_nearest', values='last_price').plot(grid=True,title='Price_from_CityCenters_Nearest', figsize=(12, 8));

# %% [markdown]
# * Вывод: На графике видно, что чем ближе расположение кваритры к центру тем цена выше, основное скопление дорогостоящих квартир до 10.000м. Центр - это удобство, близость до основных объектов инфраструктуры, транспортная доступность. Центр часто более ухоженный и имеет свои особенности архитектуры или изюминки градостроения, и добираться легче в любую часть города.

# %% [markdown]
# ### Изучите зависимость от даты размещения: дня недели, месяца и года.

# %% [markdown]
# 1. Построил графики зависимости от дня недели, месяца и года применив метод plot().

# %%
apartments_for_sale.pivot_table(index='weekday', values='last_price').plot(grid=True, title='Price_from_Weekday', figsize=(12, 8));
apartments_for_sale.pivot_table(index='month', values='last_price').plot(grid=True, title='Price_from_Month', figsize=(12, 8));
apartments_for_sale.pivot_table(index='year', values='last_price').plot(grid=True,title='Price_from_Year', figsize=(12, 8));

# %% [markdown]
# 2. Вывел число записей в категории 'день недели'. В четверг максимум объявлений, а минимум в воскресенье.

# %%
apartments_for_sale['weekday'].value_counts()
# Out:
# 3    4249
# 1    4143
# 4    3965
# 2    3929
# 0    3582
# 5    1908
# 6    1679
# Name: weekday, dtype: int64

# %% [markdown]
# 3. Вывел число записей в категории 'месяц'. Максимум объявлений в феврале месяце, а минимум в мае.

# %%
apartments_for_sale['month'].value_counts()
# Out:
# 2     2623
# 3     2555
# 11    2350
# 4     2350
# 10    2094
# 9     1962
# 6     1743
# 8     1733
# 7     1674
# 12    1625
# 1     1487
# 5     1259
# Name: month, dtype: int64

# %% [markdown]
# 4. Вывел число записей в категории 'год'. Максимум объявлений в 2018 году, а минимум в 2014.

# %%
apartments_for_sale['year'].value_counts()
# Out:
# 2018    8443
# 2017    8111
# 2019    2848
# 2016    2746
# 2015    1171
# 2014     136
# Name: year, dtype: int64

# %% [markdown]
# * Вывод: По графикам видно, что самая большая стоимость кваритры по показателям размещения объявления: день недели, месяц, год, выходит: день недели - четверг, месяц - апрель, год - 2014. Минимальная стоимость: день недели - воскресение, месяц - октябрь, год - 2018.

# %% [markdown]
# ### Зависимость цены от того, на каком этаже расположена квартира.

# %%
apartments_for_sale.pivot_table(index='floor', values='last_price').plot(grid=True,title='Price_from_Floor', figsize=(12, 6));

# %% [markdown]
# * Вывод: на графике видно, что квартиры на первом этаже самые дешевые, а самые дорогие на последнем. Первый этаж действительно менее предпочтителен, причины тому, шумы с улицы, ворам проще пробраться, да и вид из окна первого этажа не сравнится с более высокими этажами.

# %% [markdown]
# ### Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце 'locality_name'.

# %% [markdown]
# 1. Нашел 10 населенных пунктов с самым большим числом объявлений методами value_counts() и sort_values().

# %%
apartments_for_sale.loc[:,'locality_name'].value_counts().sort_values(ascending=False).head(10)
# Out:
# Санкт-Петербург      15520
# посёлок Мурино         518
# посёлок Шушары         439
# Всеволожск             396
# Пушкин                 365
# Колпино                338
# посёлок Парголово      327
# Гатчина                305
# деревня Кудрово        299
# Выборг                 235
# Name: locality_name, dtype: int64

# %% [markdown]
# 2. Применил метод query() для выделения 10 населенных пунктов с самым большим числом объявлений, сгрупировал данные при помощи pivot_table() и построил график зависимости стоимости жилья в зависимости от населенного пункта.

# %%
max_exposition = apartments_for_sale.query('locality_name in ("Санкт-Петербург", "посёлок Мурино", "посёлок Шушары""Всеволожск", "Пушкин", "Колпино", "посёлок Парголово", "Гатчина", "деревня Кудрово", "Выборг")')
max_exposition.pivot_table(index='locality_name', values='last_price').plot(grid=True,title='Price_from_Locality_Name_with_Max_Exposition', figsize=(15, 12));

# %% [markdown]
# * Вывод: Из 10 населенных пунктов в Санкт_Петербурге самая большая стоимость жилья, а в Выборге самая низкая.

# %% [markdown]
# 3. Построил график зависимости средней стоимости квадратного метра от 10 населенных пунктов имеющих самые большие показатели по количеству объявлений.

# %%
max_exposition.pivot_table(index='locality_name', values='price_area', aggfunc='mean').plot(grid=True,title='Mean_Price_from_Locality_Name_with_Max_Exposition', figsize=(15, 12));

# %% [markdown]
# * Вывод: Самая высокая средняя стоимость квадратного метра наблюдается в Санкт-петербурге, самая низкая в Выборге. Прослеживается очевидная зависимость, чем крупнее город, тем больше объявлений о продаже кваритр и соответственно стоимость там выше чем в небольших населенных пунктах.

# %% [markdown]
# ### Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге ('locality_name'). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.

# %% [markdown]
# 1. Выделил квартиры в Санкт_Петербурге и нашел для каждой расстояние до центра, значения записал в столбец 'centers_nearest', поменял тип данных на целочисленный, пустые значения заменил на 0.

# %%
apartments_for_sale['cityCenters_nearest'] = apartments_for_sale['cityCenters_nearest'].astype('int')
apartments_for_sale['centers_nearest'] = apartments_for_sale.loc[apartments_for_sale.loc[:,'locality_name'] == 'Санкт-Петербург']['cityCenters_nearest']
apartments_for_sale['centers_nearest'] = apartments_for_sale['centers_nearest'].fillna(0)

# %% [markdown]
# 2. Сгруппировал данные и посчитал среднюю стоимость в зависимости от удаленности с помощью pivot_table(), далее построил график применяя метод plot().

# %%
mean_price_km = apartments_for_sale.pivot_table(index='centers_nearest', values='last_price', aggfunc='mean')
mean_price_km.plot(grid=True,title='Mean_Last_Price_from_Centers_Nearest', figsize=(10, 5));

# %% [markdown]
# * Вывод: Судя по графику центральная зона начинается в районе 6000м.

# %% [markdown]
# ### Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?

# %% [markdown]
# 1. Построил гистограмму по столбцу 'total_area' методом hist(), чтобы изучить частоту разных значений площади квартир расположенных в центре города.

# %%
apartments_for_sale.query('centers_nearest < 6000').plot(y='total_area', title='Total_area_near_center', grid=True, kind='hist', bins=10, range=(0, 400))
plt.show()

# %% [markdown]
# 2. Построил гистограмму по столбцу 'last_price' методом hist(), чтобы изучить частоту разных значений стоимости квартир расположенных в центре города.

# %%
apartments_for_sale.query('centers_nearest < 6000').plot(y='last_price',title='Price_apartment_near_center', grid=True, kind='hist', bins=10, range=(0, 20000000))
plt.show()

# %% [markdown]
# 3. Построил гистограмму по столбцу 'rooms' методом hist(), чтобы изучить частоту разных значений количества комнат в  квартире расположенных в центре города.

# %%
apartments_for_sale.query('centers_nearest < 6000').plot(y='rooms',title='Rooms_near_center', grid=True, kind='hist', bins=10, range=(0, 10))
plt.show()

# %% [markdown]
# 4. Построил гистограмму по столбцу 'ceiling_height' методом hist(), чтобы изучить частоту разных значений высоты потолков в квартире расположенных в центре города.

# %%
apartments_for_sale.query('centers_nearest < 6000').plot(y='ceiling_height', title='Ceiling_height_near_center', grid=True, kind='hist', bins=10, range=(1, 5))
plt.show()

# %% [markdown]
# 5. Построил график зависимости цены от количества комнат обращаясь к pivot_table() и используя метод plot(). Построил график для центра города и для всего города.

# %%
apartments_for_sale.query('centers_nearest < 6000').pivot_table(index='rooms', values='last_price').plot(grid=True, title='Price_from_Rooms_Near_Center', figsize=(12, 8));

# %%
apartments_for_sale.query('centers_nearest').pivot_table(index='rooms', values='last_price').plot(grid=True, title='Price_from_Rooms_All_Over_the_City', figsize=(12, 9));

# %% [markdown]
# * Вывод: Графики зависимости цены от количеств комнат в центре и по всему городу имеют разные характеры, в центре оказалась самой дорогой 8 комнатная квартира, а по всему городу самой дорогостоящей 6 комнатная квартира.

# %% [markdown]
# 6. Построил график зависимости цены от удаленности от центра в районе 6000м и по всему городу, обращаясь к pivot_table() и используя метод plot().

# %%
apartments_for_sale.query('centers_nearest < 6000').pivot_table(index='centers_nearest', values='last_price').plot(grid=True,title='Price_from_Centers_Nearest_Near_Center', figsize=(12, 8));

# %%
apartments_for_sale.query('centers_nearest').pivot_table(index='centers_nearest', values='last_price').plot(grid=True, title='Price_from_Centers_Nearest_All_Over_the_City',figsize=(12, 8));

# %% [markdown]
# * Вывод: По графикам видно, что самые дорогостоящие квартиры расположены ближе к центру.

# %% [markdown]
# 7. Построил график зависимости цены от этажа в центре города и по всему городу, обращаясь к pivot_table() и используя метод plot().

# %%
apartments_for_sale.query('centers_nearest < 6000').pivot_table(index='floor', values='last_price').plot(grid=True, title='Price_from_Floor_Near_Center');

# %%
apartments_for_sale.query('centers_nearest').pivot_table(index='floor', values='last_price').plot(grid=True, title='Price_from_Floor_All_Over_the_City');

# %% [markdown]
# * Вывод: Графики зависимости цены от этажа имеют одинаковый характер, что в центре города, что по всему городу.

# %% [markdown]
# 8. Построил график зависимости цены от даты размещения объявления в центре города и по всему городу, обращайясь к pivot_table() и используя метод plot().

# %%
apartments_for_sale.query('centers_nearest < 6000').pivot_table(index='weekday', values='last_price').plot(grid=True, title='Price_from_Weekday_Near_Center', figsize=(12, 8));
apartments_for_sale.query('centers_nearest < 6000').pivot_table(index='month', values='last_price').plot(grid=True, title='Price_from_Month_Near_Center', figsize=(12, 8));
apartments_for_sale.query('centers_nearest < 6000').pivot_table(index='year', values='last_price').plot(grid=True, title='Price_from_Year_Near_Center', figsize=(12, 8));

# %%
apartments_for_sale.query('centers_nearest').pivot_table(index='weekday', values='last_price').plot(grid=True, title='Price_from_Weekday_All_Over_the_City', figsize=(12, 8));
apartments_for_sale.query('centers_nearest').pivot_table(index='month', values='last_price').plot(grid=True, title='Price_from_Month_All_Over_the_City', figsize=(12, 8));
apartments_for_sale.query('centers_nearest').pivot_table(index='year', values='last_price').plot(grid=True, title='Price_from_Year_All_Over_the_City', figsize=(12, 8));

# %% [markdown]
# * Вывод: Графики зависимости цены от даты размещения объявления в центре города и по всему городу имеют различный характер, кроме зависимости по годам, тут графики схожи с небольшими отклонениями. Например минимальная стоимость в центре города по дню недели - суббота, а по месяцу - июнь; минимальная стоимость по всему городу по дню недели - воскресенье, а по месяцу - май.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# * Больше всего продаж происходит в течение 1-3 месяцев с момента публикации объявления, чаще всего продаются квартиры имеющие 1-3 комнаты и размер потолков 2,5-2,8м это самые ходовые квартиры. Квартиры на первом этаже дешевле чем на остальных этажах. Самая большая стоимость кваритры по показателям размещения объявления: день недели, месяц, год, выходит: день недели - четверг, месяц - апрель, год - 2014. Минимальная стоимость: день недели - воскресение, месяц - октябрь, год - 2018. Чем больше площадь квартиры и ближе её расположение к центру, тем дороже её стоимость.
#
# *   Судя по полученным данным, количество объявлений очень сильно выросло, на 2014г - 136 объявлений, а на 2018г - 8443, связано это с расширяющимся градостроительством, особенно в крупных городах. Судя по показателям цены за период 2014г-2018г, стоимость жилья снизилась, что говорит об увелечении доступности жилья для приобретения. Средний показатель цены за 2014г - 11.5 млн.р, а за 2018г-5.5 млн.р.
#
# *   Если есть желание приобрести квартиру, то объявления стоит смотреть в октябре месяце, в конце недели. Самые дешевые объявления выпадают именно в этот период.
